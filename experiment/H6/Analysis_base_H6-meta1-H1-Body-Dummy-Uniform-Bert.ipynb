# %%
import pandas as pd
import numpy as np
import csv 
import matplotlib.pyplot as plt
import seaborn as sns


#https://altair-viz.github.io/gallery/errorbars_with_std.html
#import altair as alt
#from vega_datasets import data

#defining paths
allAlgorithms_unigram_900terms = './data/All_H1v3.csv'
#classifierChain = './experiment/dfTesteClassifierChain_13Labels.csv'


dataBinary = pd.read_csv(allAlgorithms_unigram_900terms)
#dataClassifier = pd.read_csv(classifierChain)

# %%
dataBinaryBasexH6 = pd.read_csv(allAlgorithms_unigram_900terms)
dataBinaryBasexH6['Hypothesis'] = np.where(dataBinaryBasexH6['Algorithm']=='RandomForest', 'baseline', 'H6')
dataBinaryBasexH6.head()
# Out:
#       date_time  tf-IDF  #_TopTerms Stop_Word  Train/Test_Size     Algorithm  \
# 0  9/15/21 9:30  (1, 1)         216       Yes              0.2  RandomForest
# 1  9/15/21 9:30  (1, 1)         216       Yes              0.2  RandomForest
# 2  9/15/21 9:30  (1, 1)         216       Yes              0.2  RandomForest
# 3  9/15/21 9:30  (1, 1)         216       Yes              0.2  RandomForest
# 4  9/15/21 9:30  (1, 1)         216       Yes              0.2  RandomForest
#
#    Accuracy_Score  Accuracy_Score_not_normalized  zero_one_loss    AUC-PR  \
# 0        0.628571                             22       0.371429  0.980134
# 1        0.742857                             26       0.257143  0.546429
# 2        0.742857                             26       0.257143  0.993743
# 3        0.628571                             22       0.371429  0.542857
# 4        0.657143                             23       0.342857  0.990640
#
# ...

# %%
dataBinary = dataBinary[dataBinary.project != 'presto']
dataBinary = dataBinary[dataBinary.project != 'jabref']
dataBinary = dataBinary[dataBinary.project != 'guava']
dataBinary = dataBinary[dataBinary.project != 'mockito']
dataBinary = dataBinary[dataBinary.project != 'rxjava']

dataBinary.head()
# Out:
#           date_time  tf-IDF  #_TopTerms Stop_Word  Train/Test_Size  \
# 2280  9/20/21 21:31  (1, 1)         838       Yes              0.2
# 2281  9/20/21 21:31  (1, 1)         838       Yes              0.2
# 2282  9/20/21 21:31  (1, 1)         838       Yes              0.2
# 2283  9/20/21 21:31  (1, 1)         838       Yes              0.2
# 2284  9/20/21 21:31  (1, 1)         838       Yes              0.2
#
#          Algorithm  Accuracy_Score  Accuracy_Score_not_normalized  \
# 2280  RandomForest        0.304094                             52
# 2281  RandomForest        0.257310                             44
# 2282  RandomForest        0.286550                             49
# 2283  RandomForest        0.269006                             46
# 2284  RandomForest        0.286550                             49
#
#       zero_one_loss    AUC-PR  hamming_loss_avg  Jaccard_samples  \
# 2280       0.695906  0.903477          0.115789         0.724704
# ...

# %%
dataBinaryBasexH6 = dataBinaryBasexH6[dataBinaryBasexH6.project != 'presto']
dataBinaryBasexH6 = dataBinaryBasexH6[dataBinaryBasexH6.project != 'jabref']
dataBinaryBasexH6 = dataBinaryBasexH6[dataBinaryBasexH6.project != 'guava']
dataBinaryBasexH6 = dataBinaryBasexH6[dataBinaryBasexH6.project != 'mockito']
dataBinaryBasexH6 = dataBinaryBasexH6[dataBinaryBasexH6.project != 'rxjava']

dataBinaryBasexH6.head()
# Out:
#           date_time  tf-IDF  #_TopTerms Stop_Word  Train/Test_Size  \
# 2280  9/20/21 21:31  (1, 1)         838       Yes              0.2
# 2281  9/20/21 21:31  (1, 1)         838       Yes              0.2
# 2282  9/20/21 21:31  (1, 1)         838       Yes              0.2
# 2283  9/20/21 21:31  (1, 1)         838       Yes              0.2
# 2284  9/20/21 21:31  (1, 1)         838       Yes              0.2
#
#          Algorithm  Accuracy_Score  Accuracy_Score_not_normalized  \
# 2280  RandomForest        0.304094                             52
# 2281  RandomForest        0.257310                             44
# 2282  RandomForest        0.286550                             49
# 2283  RandomForest        0.269006                             46
# 2284  RandomForest        0.286550                             49
#
#       zero_one_loss    AUC-PR  hamming_loss_avg  Jaccard_samples  \
# 2280       0.695906  0.903477          0.115789         0.724704
# ...

# %%
dataBinary.shape
# Out:
# (2406, 18)

# %%
dataBinaryBasexH6.shape
# Out:
# (2406, 19)

# %%
dataBinary.dropna(subset = ["Algorithm"], inplace=True)
dataBinaryBasexH6.dropna(subset = ["Algorithm"], inplace=True)

# %%
dataBinary.shape
# Out:
# (2406, 18)

# %%
dataBinaryBasexH6.shape
# Out:
# (2406, 19)

# %%
#TODO: Determine which cross validations pair is best for BERT and build it here.
allbert = './data/BertMetricsNewCV.csv'
#classifierChain = './experiment/dfTesteClassifierChain_13Labels.csv'


dataBinaryBert = pd.read_csv(allbert)
#dataClassifier = pd.read_csv(classifierChain)frames = [dataBinary, dataBinaryDumnmy]


#dataBinaryBert

frames = [dataBinary, dataBinaryBert]

dataBinary = pd.concat(frames)
dataBinary.to_csv('./data/All_corpus_with_bertCV.csv', index=False)

# %%
dataBinary.shape
# Out:
# (2526, 18)

# %%
alldummies = './data/All_H1_Dummy_uniform_dfTeste.csv'
#classifierChain = './experiment/dfTesteClassifierChain_13Labels.csv'


dataBinaryDummies = pd.read_csv(alldummies)
#dataClassifier = pd.read_csv(classifierChain)frames = [dataBinary, dataBinaryDumnmy]
frames = [dataBinary, dataBinaryDummies]

dataBinary = pd.concat(frames)

dataBinary.to_csv('./data/All_corpus_with_dummies_uniform_bertCV.csv', index=False)

# %%
dataBinary.shape
# Out:
# (2576, 18)

# %%
pd.options.display.max_colwidth = None
pd.options.display.max_rows = None
pd.options.display.max_seq_items = None
pd.set_option('display.max_columns', None)

# %%
dataBinary.head()
# Out:
#           date_time  tf-IDF  #_TopTerms Stop_Word  Train/Test_Size  \
# 2280  9/20/21 21:31  (1, 1)       838.0       Yes              0.2
# 2281  9/20/21 21:31  (1, 1)       838.0       Yes              0.2
# 2282  9/20/21 21:31  (1, 1)       838.0       Yes              0.2
# 2283  9/20/21 21:31  (1, 1)       838.0       Yes              0.2
# 2284  9/20/21 21:31  (1, 1)       838.0       Yes              0.2
#
#          Algorithm  Accuracy_Score  Accuracy_Score_not_normalized  \
# 2280  RandomForest        0.304094                           52.0
# 2281  RandomForest        0.257310                           44.0
# 2282  RandomForest        0.286550                           49.0
# 2283  RandomForest        0.269006                           46.0
# 2284  RandomForest        0.286550                           49.0
#
#       zero_one_loss    AUC-PR  hamming_loss_avg  Jaccard_samples  \
# 2280       0.695906  0.903477          0.115789         0.724704
# ...

# %%
dd=pd.melt(dataBinaryBasexH6,id_vars=['Hypothesis'],value_vars=['Precision','Recall','Fmeasure_Score'],var_name='Evaluation Metrics')

plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='value',x='Hypothesis',data=dd,hue='Evaluation Metrics')
plt.ylabel("Performance", size=14)
plt.xlabel("Evaluation Metrics by Hypothesis",size=14)

#labels=["Precision", "Recall", "F-measure"]
#h, l = ax.get_legend_handles_labels()
#ax.legend(h, labels, title="Evaluation Metrics",bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
#plt.title("Evaluation Metrics by Hypothesis", size=12)
plt.savefig("BaselinexH6.pdf")
plt.show()
#plt.savefig("grouped_boxplot_AlgorithmBinary.png")

# %%
dd=pd.melt(dataBinary,id_vars=['Algorithm'],value_vars=['Precision','Recall','Fmeasure_Score'],var_name='Evaluation Metrics')

plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='value',x='Algorithm',data=dd,hue='Evaluation Metrics')
plt.ylabel("Performance", size=14)
#plt.xlabel("Evaluation Metrics by Hypothesis",size=14)

labels=["Precision", "Recall", "F-measure"]
#h, l = ax.get_legend_handles_labels()
#ax.legend(h, labels, title="Evaluation Metrics",bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
#plt.title("Evaluation Metrics by Algorithm", size=12)
plt.savefig("BaselinexH6Algv3Bert.pdf")

plt.show()
#plt.savefig("grouped_boxplot_AlgorithmBinary.png")

# %%
dd=pd.melt(dataBinary,id_vars=['Algorithm'],value_vars=['Accuracy_Score','Precision','Recall','Fmeasure_Score'],var_name='Evaluation Metrics')

plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='value',x='Algorithm',data=dd,hue='Evaluation Metrics')
plt.ylabel("Performance", size=14)
#plt.xlabel("Evaluation Metrics by Hypothesis",size=14)

labels=["Accuracy_Score","Precision", "Recall", "F-measure"]
#h, l = ax.get_legend_handles_labels()
#ax.legend(h, labels, title="Evaluation Metrics",bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
#plt.title("Evaluation Metrics by Algorithm", size=12)
plt.savefig("BaselinexH6AlgBertAccuracy.pdf")

plt.show()
#plt.savefig("grouped_boxplot_AlgorithmBinary.png")

# %%
db_alg = dataBinary.groupby(['Algorithm']).mean()
db_alg
# Out:
#                      #_TopTerms  Train/Test_Size  Accuracy_Score  \
# Algorithm
# BERT                        NaN         0.300000        0.722679
# DecisionTree        1188.500000         0.300000        0.409089
# Dummy               1741.800000         0.200000        0.000385
# LogisticRegression  1181.235294         0.299160        0.291321
# MLPClassifier       1188.500000         0.300000        0.412162
# MLkNN               1188.500000         0.300000        0.346654
# RandomForest        1206.142857         0.297959        0.390468
#
#                     Accuracy_Score_not_normalized  zero_one_loss    AUC-PR  \
# Algorithm
# BERT                                          NaN            NaN       NaN
# DecisionTree                            48.870833       0.590911  0.845301
# Dummy                                    0.020000       0.999615  0.380146
# LogisticRegression                      33.266807       0.708679  0.908935
# ...

# %%
db_alg[['Accuracy_Score','Precision','Recall','Fmeasure_Score','hamming_loss_avg', ]]
# Out:
#                     Accuracy_Score  Precision    Recall  Fmeasure_Score  \
# Algorithm
# BERT                      0.722679   0.601338  0.574894        0.578236
# DecisionTree              0.409089   0.866169  0.826953        0.844011
# Dummy                     0.000385   0.382425  0.504650        0.427088
# LogisticRegression        0.291321   0.855884  0.806320        0.828833
# MLPClassifier             0.412162   0.860004  0.837159        0.846729
# MLkNN                     0.346654   0.845792  0.808224        0.823813
# RandomForest              0.390468   0.860036  0.840599        0.849075
#
#                     hamming_loss_avg
# Algorithm
# BERT                        0.277321
# DecisionTree                0.109872
# Dummy                       0.497756
# LogisticRegression          0.120849
# MLPClassifier               0.110207
# MLkNN                       0.123165
# RandomForest                0.107539

# %%
dataBinary.nlargest(50,['Precision','Fmeasure_Score']).head()
# Out:
#          date_time  tf-IDF  #_TopTerms Stop_Word  Train/Test_Size  \
# 3525  1/17/22 9:26  (1, 1)       973.0       Yes              0.2
# 3515  1/17/22 9:25  (1, 1)       973.0       Yes              0.2
# 3665  1/17/22 9:29  (2, 2)       973.0       Yes              0.2
# 3495  1/17/22 9:25  (1, 1)       973.0       Yes              0.2
# 3655  1/17/22 9:29  (2, 2)       973.0       Yes              0.2
#
#                Algorithm  Accuracy_Score  Accuracy_Score_not_normalized  \
# 3525       MLPClassifier        0.653846                           34.0
# 3515  LogisticRegression        0.576923                           30.0
# 3665  LogisticRegression        0.557692                           29.0
# 3495        RandomForest        0.653846                           34.0
# 3655        DecisionTree        0.615385                           32.0
#
#       zero_one_loss    AUC-PR  hamming_loss_avg  Jaccard_samples  \
# 3525       0.346154  0.985782          0.073077         0.865949
# ...

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='Accuracy_Score',x='Algorithm',data=dataBinary)
plt.ylabel("Accuracy_Score distribution", size=12)
plt.xlabel("Algorithm",size=12)
plt.title("Classifier Chain - AUCpr Analysis", size=12)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='AUC-PR',x='Algorithm',data=dataBinary)
plt.ylabel("AUCpr distribution", size=12)
plt.xlabel("Algorithm",size=12)
plt.title("Classifier Chain - AUCpr Analysis", size=12)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='AUC-PR',x='Hypothesis',data=dataBinaryBasexH6)
plt.ylabel("AUCpr distribution", size=12)
plt.xlabel("Hypothesis",size=12)
plt.title("Classifier Chain - AUCpr Analysis", size=12)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='hamming_loss_avg',x='Algorithm',data=dataBinary)
plt.ylabel("Hamming Loss Average distribution", size=12)
plt.xlabel("Algorithm",size=12)
plt.title("Classifier Chain - Hamming Loss Analysis", size=12)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='hamming_loss_avg',x='Hypothesis',data=dataBinaryBasexH6)
plt.ylabel("Hamming Loss Average distribution", size=12)
plt.xlabel("Algorithm",size=12)
plt.title("Classifier Chain - Hamming Loss Analysis", size=12)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='Accuracy_Score_not_normalized',x='Algorithm',data=dataBinary)
plt.ylabel("PR's correctly predicted", size=12)
plt.xlabel("Algorithms",size=12)
plt.title("Classifier Chain - Number of PR correctly predict considering all APIs", size=12)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='Accuracy_Score_not_normalized',x='Hypothesis',data=dataBinaryBasexH6)
plt.ylabel("PR's correctly predicted", size=12)
plt.xlabel("Algorithms",size=12)
plt.title("Classifier Chain - Number of PR correctly predict considering all APIs", size=12)
plt.show()

# %%
def cliffsDelta(lst1, lst2, **dull):

    """Returns delta and true if there are more than 'dull' differences"""
    if not dull:
        dull = {'small': 0.147, 'medium': 0.33, 'large': 0.474} # effect sizes from (Hess and Kromrey, 2004)
    m, n = len(lst1), len(lst2)
    lst2 = sorted(lst2)
    j = more = less = 0
    for repeats, x in runs(sorted(lst1)):
        while j <= (n - 1) and lst2[j] < x:
            j += 1
        more += j*repeats
        while j <= (n - 1) and lst2[j] == x:
            j += 1
        less += (n - j)*repeats
    d = (more - less) / (m*n)
    size = lookup_size(d, dull)
    return d, size


def lookup_size(delta: float, dull: dict) -> str:
    """
    :type delta: float
    :type dull: dict, a dictionary of small, medium, large thresholds.
    """
    delta = abs(delta)
    if delta < dull['small']:
        return 'negligible'
    if dull['small'] <= delta < dull['medium']:
        return 'small'
    if dull['medium'] <= delta < dull['large']:
        return 'medium'
    if delta >= dull['large']:
        return 'large'


def runs(lst):
    """Iterator, chunks repeated values"""
    for j, two in enumerate(lst):
        if j == 0:
            one, i = two, 0
        if one != two:
            yield j - i, one
            i = j
        one = two
    yield j - i + 1, two

# %%
#https://machinelearningmastery.com/effect-size-measures-in-python/
#Small Effect Size: d=0.20
#Medium Effect Size: d=0.50
#Large Effect Size: d=0.80

from numpy import mean
from numpy import var
from math import sqrt

def cohend(d1, d2):
	# calculate the size of samples
	n1, n2 = len(d1), len(d2)
	# calculate the variance of the samples
	s1, s2 = var(d1, ddof=1), var(d2, ddof=1)
	# calculate the pooled standard deviation
	s = sqrt(((n1 - 1) * s1 + (n2 - 1) * s2) / (n1 + n2 - 2))
	# calculate the means of the samples
	u1, u2 = mean(d1), mean(d2)
	# calculate the effect size
	return (u1 - u2) / s

# %%
RF_binary = dataBinary[dataBinary.Algorithm == 'RandomForest']
RF_FMeasure = RF_binary['Fmeasure_Score']

LogisticRegression_binary = dataBinary[dataBinary.Algorithm == 'LogisticRegression']
LogisticRegression_FMeasure = LogisticRegression_binary['Fmeasure_Score']

MLPC_binary = dataBinary[dataBinary.Algorithm == 'MLPClassifier']
MLPC_FMeasure = MLPC_binary['Fmeasure_Score']

DT_binary = dataBinary[dataBinary.Algorithm == 'DecisionTree']
DT_FMeasure = DT_binary['Fmeasure_Score']

MlkNN_binary = dataBinary[dataBinary.Algorithm == 'MLkNN']
MlkNN_FMeasure = MlkNN_binary['Fmeasure_Score']

Dummy_binary = dataBinary[dataBinary.Algorithm == 'Dummy']
Dummy_FMeasure = Dummy_binary['Fmeasure_Score']

#Dummy1_binary = dataBinary[dataBinary.Algorithm == 'Dummy1']
#Dummy1_FMeasure = Dummy1_binary['Fmeasure_Score']

Bert_binary = dataBinary[dataBinary.Algorithm == 'Bert']
Bert_FMeasure = Dummy_binary['Fmeasure_Score']

# %%
#### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('RF x LR')
# compare samples
stat, p = mannwhitneyu(RF_FMeasure, LogisticRegression_FMeasure)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

#### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

print('RF x MLPC')
# compare samples
stat, p = mannwhitneyu(RF_FMeasure, MLPC_FMeasure)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
    #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('RF x DT')
# compare samples
stat, p = mannwhitneyu(RF_FMeasure, DT_FMeasure)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
        #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('RF x MlkNN')
# compare samples
stat, p = mannwhitneyu(RF_FMeasure, MlkNN_FMeasure)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

##### Defining variables to be comparede
print('RF x Bert')
# compare samples
stat, p = mannwhitneyu(RF_FMeasure, Bert_FMeasure)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

        #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('LR x MLPC')
# compare samples
stat, p = mannwhitneyu(LogisticRegression_FMeasure, MLPC_FMeasure)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
            #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('LR x DT')
# compare samples
stat, p = mannwhitneyu(LogisticRegression_FMeasure, DT_FMeasure)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
                #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('LR x MlkNN')
# compare samples
stat, p = mannwhitneyu(LogisticRegression_FMeasure, MlkNN_FMeasure)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('LR x Bert')
# compare samples
stat, p = mannwhitneyu(LogisticRegression_FMeasure,Bert_FMeasure)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
                #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('MLPC x DT')
# compare samples
stat, p = mannwhitneyu(MLPC_FMeasure, DT_FMeasure)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
                #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('MLPC x MlkNN')
# compare samples
stat, p = mannwhitneyu(MLPC_FMeasure, MlkNN_FMeasure)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('MLPC x Bert')
# compare samples
stat, p = mannwhitneyu(MLPC_FMeasure, Bert_FMeasure)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
                    #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('MlkNN x DT')
# compare samples
stat, p = mannwhitneyu(MlkNN_FMeasure, DT_FMeasure)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

    #Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('MlkNN x Bert')
# compare samples
stat, p = mannwhitneyu(MlkNN_FMeasure, Bert_FMeasure)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

    #Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('DT x Bert')
# compare samples
stat, p = mannwhitneyu(DT_FMeasure, Bert_FMeasure)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

print('RF x Dummy')
stat, p = mannwhitneyu(RF_FMeasure, Dummy_FMeasure)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

#stat, p = mannwhitneyu(RF_FMeasure, Dummy1_FMeasure)
#print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
#alpha = 0.05
#if p > alpha:
#	print('Same distribution (fail to reject H0)')
#else:#
#	print('Different distribution (reject H0)')
    
print('Effect_Size RandomForest Vs others ')  
print(cliffsDelta(RF_FMeasure, LogisticRegression_FMeasure))
print(cliffsDelta(RF_FMeasure, MLPC_FMeasure))
print(cliffsDelta(RF_FMeasure, DT_FMeasure))
print(cliffsDelta(RF_FMeasure, MlkNN_FMeasure)) #divisionByZero error
print(cliffsDelta(RF_FMeasure, Bert_FMeasure))

print('Effect_Size LogisticRegression Vs others')
print(cliffsDelta(LogisticRegression_FMeasure, MLPC_FMeasure))
print(cliffsDelta(LogisticRegression_FMeasure, DT_FMeasure))
print(cliffsDelta(LogisticRegression_FMeasure, MlkNN_FMeasure))
print(cliffsDelta(LogisticRegression_FMeasure, Bert_FMeasure))

print('Effect_Size MLPC Vs others')
print(cliffsDelta(MLPC_FMeasure, DT_FMeasure))
print(cliffsDelta(MLPC_FMeasure, MlkNN_FMeasure))
print(cliffsDelta(MLPC_FMeasure, Bert_FMeasure))

print('Effect_Size MlkNN Vs others')
print(cliffsDelta(MlkNN_FMeasure,DT_FMeasure))
print(cliffsDelta(MlkNN_FMeasure, Bert_FMeasure)) #divisionByZero error

# Dummy
print('RFxDummy',cliffsDelta(RF_FMeasure, Dummy_FMeasure))
#print(cliffsDelta(RF_FMeasure, Dummy1_FMeasure))

print('Effect_Size Bert Vs others')   
print(cliffsDelta(DT_FMeasure, Bert_FMeasure))
print(cliffsDelta(Dummy_FMeasure, Bert_FMeasure)) #divisionByZero error
# Out:
# RF x LR
# Statistics=148723.00000, p=0.00000
# Different distribution (reject H0)
# RF x MLPC
# Statistics=120711.00000, p=0.47584
# Same distribution (fail to reject H0)
# RF x DT
# Statistics=125217.00000, p=0.08083
# Same distribution (fail to reject H0)
# RF x MlkNN
# Statistics=151062.50000, p=0.00000
# Different distribution (reject H0)
# RF x Bert
# Statistics=24500.00000, p=0.00000
# Different distribution (reject H0)
# LR x MLPC
# Statistics=89576.50000, p=0.00000
# Different distribution (reject H0)
# LR x DT
# Statistics=96608.50000, p=0.00004
# Different distribution (reject H0)
# LR x MlkNN
# Statistics=123143.00000, p=0.03702
# Different distribution (reject H0)
# LR x Bert
# Statistics=23800.00000, p=0.00000
# Different distribution (reject H0)
# MLPC x DT
# Statistics=119002.50000, p=0.37609
# Same distribution (fail to reject H0)
# MLPC x MlkNN
# Statistics=143001.00000, p=0.00000
# Different distribution (reject H0)
# MLPC x Bert
# Statistics=24000.00000, p=0.00000
# ...

# %%
##Kruskall Wallis - Group Comparison

#Fail to Reject H0: Paired sample distributions are equal.
#Reject H0: Paired sample distributions are not equal.
    
from scipy.stats import kruskal
# seed the random number generator


# compare samples
stat, p = kruskal(RF_FMeasure,LogisticRegression_FMeasure, MLPC_FMeasure,DT_FMeasure,MlkNN_FMeasure, Dummy_FMeasure)#, Dummy1_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=239.095, p=0.000
# Different distributions (reject H0)

# %%
#https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
from scipy.stats import friedmanchisquare

# compare samples
stat, p = friedmanchisquare(RF_FMeasure,LogisticRegression_FMeasure,MLPC_FMeasure,DT_FMeasure,MlkNN_FMeasure, Dummy_FMeasure)#, Dummy1_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-08f20e35e171> in <module>
#       3
#       4 # compare samples
# ----> 5 stat, p = friedmanchisquare(RF_FMeasure,LogisticRegression_FMeasure,MLPC_FMeasure,DT_FMeasure,MlkNN_FMeasure, Dummy_FMeasure)#, Dummy1_FMeasure)
#       6 print('Statistics=%.3f, p=%.3f' % (stat, p))
#       7 # interpret
#
# C:\Python39\lib\site-packages\scipy\stats\stats.py in friedmanchisquare(*args)
#    7956     for i in range(1, k):
#    7957         if len(args[i]) != n:
# -> 7958             raise ValueError('Unequal N in friedmanchisquare.  Aborting.')
#    7959
#    7960     # Rank data
#
# ValueError: Unequal N in friedmanchisquare.  Aborting.

# %%
###Precision analysis
#Subsetting data to compute Stats

RF_binary = dataBinary[dataBinary.Algorithm == 'RandomForest']
RF_Precision = RF_binary['Precision']

LogisticRegression_binary = dataBinary[dataBinary.Algorithm == 'LogisticRegression']
LogisticRegression_Precision = LogisticRegression_binary['Precision']

MLPC_binary = dataBinary[dataBinary.Algorithm == 'MLPClassifier']
MLPC_Precision = MLPC_binary['Precision']

DT_binary = dataBinary[dataBinary.Algorithm == 'DecisionTree']
DT_Precision = DT_binary['Precision']

MlkNN_binary = dataBinary[dataBinary.Algorithm == 'MLkNN']
MlkNN_Precision = MlkNN_binary['Precision']

Dummy_binary = dataBinary[dataBinary.Algorithm == 'Dummy']
Dummy_Precision = Dummy_binary['Precision']

#Dummy1_binary = dataBinary[dataBinary.Algorithm == 'Dummy1']
#Dummy1_Precision = Dummy1_binary['Precision']

Bert_binary = dataBinary[dataBinary.Algorithm == 'Bert']
Bert_Precision = Dummy_binary['Precision']

# %%
#### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('RF x LR')
# compare samples
stat, p = mannwhitneyu(RF_Precision, LogisticRegression_Precision)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

#### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

print('RF x MLPC')
# compare samples
stat, p = mannwhitneyu(RF_Precision, MLPC_Precision)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
    #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('RF x DT')
# compare samples
stat, p = mannwhitneyu(RF_Precision, DT_Precision)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
        #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('RF x MlkNN')
# compare samples
stat, p = mannwhitneyu(RF_Precision, MlkNN_Precision)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

##### Defining variables to be comparede
print('RF x Bert')
# compare samples
stat, p = mannwhitneyu(RF_Precision, Bert_Precision)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

        #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('LR x MLPC')
# compare samples
stat, p = mannwhitneyu(LogisticRegression_Precision, MLPC_Precision)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
            #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('LR x DT')
# compare samples
stat, p = mannwhitneyu(LogisticRegression_Precision, DT_Precision)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
                #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('LR x MlkNN')
# compare samples
stat, p = mannwhitneyu(LogisticRegression_Precision, MlkNN_Precision)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('LR x Bert')
# compare samples
stat, p = mannwhitneyu(LogisticRegression_Precision,Bert_Precision)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
                #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('MLPC x DT')
# compare samples
stat, p = mannwhitneyu(MLPC_Precision, DT_Precision)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
                #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('MLPC x MlkNN')
# compare samples
stat, p = mannwhitneyu(MLPC_Precision, MlkNN_Precision)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('MLPC x Bert')
# compare samples
stat, p = mannwhitneyu(MLPC_Precision, Bert_Precision)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
                    #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('MlkNN x DT')
# compare samples
stat, p = mannwhitneyu(MlkNN_Precision, DT_Precision)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

    #Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('MlkNN x Bert')
# compare samples
stat, p = mannwhitneyu(MlkNN_Precision, Bert_Precision)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

    #Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede
print('DT x Bert')
# compare samples
stat, p = mannwhitneyu(DT_Precision, Bert_Precision)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

print('RF x Dummy')
stat, p = mannwhitneyu(RF_Precision, Dummy_Precision)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

#stat, p = mannwhitneyu(RF_Precision, Dummy1_Precision)
#print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
#alpha = 0.05
#if p > alpha:
#	print('Same distribution (fail to reject H0)')
#else:#
#	print('Different distribution (reject H0)')
    
print('Effect_Size RandomForest Vs others ')  
print(cliffsDelta(RF_Precision, LogisticRegression_Precision))
print(cliffsDelta(RF_Precision, MLPC_Precision))
print(cliffsDelta(RF_Precision, DT_Precision))
print(cliffsDelta(RF_Precision, MlkNN_Precision)) #divisionByZero error
print(cliffsDelta(RF_Precision, Bert_Precision))

print('Effect_Size LogisticRegression Vs others')
print(cliffsDelta(LogisticRegression_Precision, MLPC_Precision))
print(cliffsDelta(LogisticRegression_Precision, DT_Precision))
print(cliffsDelta(LogisticRegression_Precision, MlkNN_Precision))
print(cliffsDelta(LogisticRegression_Precision, Bert_Precision))

print('Effect_Size MLPC Vs others')
print(cliffsDelta(MLPC_Precision, DT_Precision))
print(cliffsDelta(MLPC_Precision, MlkNN_Precision))
print(cliffsDelta(MLPC_Precision, Bert_Precision))

print('Effect_Size MlkNN Vs others')
print(cliffsDelta(MlkNN_Precision,DT_Precision))
print(cliffsDelta(MlkNN_Precision, Bert_Precision)) #divisionByZero error

# Dummy
print('RFxDummy',cliffsDelta(RF_Precision, Dummy_Precision))
#print(cliffsDelta(RF_Precision, Dummy1_Precision))

print('Effect_Size Bert Vs others')   
print(cliffsDelta(DT_Precision, Bert_Precision))
print(cliffsDelta(Dummy_Precision, Bert_Precision)) #divisionByZero error
# Out:
# RF x LR
# Statistics=109458.50000, p=0.04929
# Different distribution (reject H0)
# RF x MLPC
# Statistics=116435.50000, p=0.39480
# Same distribution (fail to reject H0)
# RF x DT
# Statistics=106868.50000, p=0.00695
# Different distribution (reject H0)
# RF x MlkNN
# Statistics=101815.00000, p=0.00015
# Different distribution (reject H0)
# RF x Bert
# Statistics=0.00000, p=0.00000
# Different distribution (reject H0)
# LR x MLPC
# Statistics=105916.50000, p=0.02560
# Different distribution (reject H0)
# LR x DT
# Statistics=96701.00000, p=0.00002
# Different distribution (reject H0)
# LR x MlkNN
# Statistics=104780.50000, p=0.01335
# Different distribution (reject H0)
# LR x Bert
# Statistics=0.00000, p=0.00000
# Different distribution (reject H0)
# MLPC x DT
# Statistics=105197.50000, p=0.00994
# Different distribution (reject H0)
# MLPC x MlkNN
# Statistics=99123.50000, p=0.00009
# Different distribution (reject H0)
# MLPC x Bert
# Statistics=0.00000, p=0.00000
# ...

# %%
###Accuracy analysis
#Subsetting data to compute Stats

RF_binary = dataBinary[dataBinary.Algorithm == 'RandomForest']
RF_Accuracy_Score = RF_binary['Accuracy_Score']

LogisticRegression_binary = dataBinary[dataBinary.Algorithm == 'LogisticRegression']
LogisticRegression_Accuracy_Score = LogisticRegression_binary['Accuracy_Score']

MLPC_binary = dataBinary[dataBinary.Algorithm == 'MLPClassifier']
MLPC_Accuracy_Score = MLPC_binary['Accuracy_Score']

DT_binary = dataBinary[dataBinary.Algorithm == 'DecisionTree']
DT_Accuracy_Score = DT_binary['Accuracy_Score']

MlkNN_binary = dataBinary[dataBinary.Algorithm == 'MLkNN']
MlkNN_Accuracy_Score = MlkNN_binary['Accuracy_Score']

Dummy_binary = dataBinary[dataBinary.Algorithm == 'Dummy']
Dummy_Accuracy_Score = Dummy_binary['Accuracy_Score']

#Dummy1_binary = dataBinary[dataBinary.Algorithm == 'Dummy1']
#Dummy1_Accuracy_Score = Dummy1_binary['Accuracy_Score']

Bert_binary = dataBinary[dataBinary.Algorithm == 'Bert']
Bert_Accuracy_Score = Dummy_binary['Accuracy_Score']

# %%
#### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(RF_Accuracy_Score, LogisticRegression_Accuracy_Score)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

#### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(RF_Accuracy_Score, MLPC_Accuracy_Score)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
    #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(RF_Accuracy_Score, DT_Accuracy_Score)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
        #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(RF_Accuracy_Score, MlkNN_Accuracy_Score)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
        #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(LogisticRegression_Accuracy_Score, MLPC_Accuracy_Score)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
            #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(LogisticRegression_Accuracy_Score, DT_Accuracy_Score)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
                #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(LogisticRegression_Accuracy_Score, MlkNN_Accuracy_Score)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
    
                #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(MLPC_Accuracy_Score, DT_Accuracy_Score)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
                #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(MLPC_Accuracy_Score, MlkNN_Accuracy_Score)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
                    #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(MlkNN_Accuracy_Score, DT_Accuracy_Score)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
stat, p = mannwhitneyu(RF_Accuracy_Score, Dummy_Accuracy_Score)
print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
#stat, p = mannwhitneyu(RF_Accuracy_Score, Dummy1_Accuracy_Score)
#print('Statistics=%.5f, p=%.5f' % (stat, p))
# interpret
#alpha = 0.05
#if p > alpha:
#	print('Same distribution (fail to reject H0)')
#else:
#	print('Different distribution (reject H0)')
    
#Effect_Size RandomForest Vs others   
print(cliffsDelta(RF_Accuracy_Score, LogisticRegression_Accuracy_Score))
print(cliffsDelta(RF_Accuracy_Score, MLPC_Accuracy_Score))
print(cliffsDelta(RF_Accuracy_Score, DT_Accuracy_Score))
print(cliffsDelta(RF_Accuracy_Score, MlkNN_Accuracy_Score)) #divisionByZero error
#print(cliffsDelta(RF_Accuracy_Score, Dummy_Accuracy_Score))

#Effect_Size LogisticRegression Vs others
print(cliffsDelta(LogisticRegression_Accuracy_Score, MLPC_Accuracy_Score))
print(cliffsDelta(LogisticRegression_Accuracy_Score, DT_Accuracy_Score))
print(cliffsDelta(LogisticRegression_Accuracy_Score, MlkNN_Accuracy_Score))

#Effect_Size MLPC Vs others
print(cliffsDelta(MLPC_Accuracy_Score, DT_Accuracy_Score))
print(cliffsDelta(MLPC_Accuracy_Score, MlkNN_Accuracy_Score))

#Effect_Size MlkNN Vs others
print(cliffsDelta(MlkNN_Accuracy_Score,DT_Accuracy_Score))

#Dummy
print(cliffsDelta(RF_Accuracy_Score, Dummy_Accuracy_Score))
#print(cliffsDelta(RF_Accuracy_Score, Dummy1_Accuracy_Score))

#Effect_Size Bert Vs others   
print(cliffsDelta(Bert_Accuracy_Score, RF_Accuracy_Score))
print(cliffsDelta(Bert_Accuracy_Score, LogisticRegression_Accuracy_Score))
print(cliffsDelta(Bert_Accuracy_Score, MLPC_Accuracy_Score))
print(cliffsDelta(Bert_Accuracy_Score, DT_Accuracy_Score))
print(cliffsDelta(Bert_Accuracy_Score, MlkNN_Accuracy_Score)) #divisionByZero error
print(cliffsDelta(Bert_Accuracy_Score, Dummy_Accuracy_Score)) #divisionByZero error
# Out:
# Statistics=68880.50000, p=0.00000
# Different distribution (reject H0)
# Statistics=104746.50000, p=0.00161
# Different distribution (reject H0)
# Statistics=106810.50000, p=0.00669
# Different distribution (reject H0)
# Statistics=93674.50000, p=0.00000
# Different distribution (reject H0)
# Statistics=58896.50000, p=0.00000
# Different distribution (reject H0)
# Statistics=59755.50000, p=0.00000
# Different distribution (reject H0)
# Statistics=84105.50000, p=0.00000
# Different distribution (reject H0)
# Statistics=112752.00000, p=0.28439
# Same distribution (fail to reject H0)
# Statistics=78987.50000, p=0.00000
# Different distribution (reject H0)
# Statistics=81947.00000, p=0.00000
# Different distribution (reject H0)
# Statistics=0.00000, p=0.00000
# Different distribution (reject H0)
# (0.40935945806894186, 'medium')
# (-0.1092984693877551, 'negligible')
# (-0.09174744897959183, 'negligible')
# (0.2034481292517007, 'small')
# (-0.4844494047619048, 'large')
# ...

# %%
##Kruskall Wallis - Group Comparison

#Fail to Reject H0: Paired sample distributions are equal.
#Reject H0: Paired sample distributions are not equal.
    
from scipy.stats import kruskal
# seed the random number generator


# compare samples
stat, p = kruskal(RF_Precision,LogisticRegression_Precision, MLPC_Precision,DT_Precision,MlkNN_Precision,Dummy_Precision)#,Dummy1_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=46.312, p=0.000
# Different distributions (reject H0)

# %%
# Out:
# Statistics=54.300, p=0.000
# Different distributions (reject H0)

# %%
#Subsetting data to compute Stats

Baseline_binary = dataBinary[dataBinary.Hypothesis == 'Baseline']
Baseline_FMeasure = Baseline_binary['Fmeasure_Score']

H6_binary = dataBinary[dataBinary.Hypothesis == 'H6']
H6_FMeasure = H6_binary['Fmeasure_Score']

# %%
##Kruskall Wallis - Group Comparison

#Fail to Reject H0: Paired sample distributions are equal.
#Reject H0: Paired sample distributions are not equal.
    
from scipy.stats import kruskal
# seed the random number generator


# compare samples
stat, p = kruskal(Baseline_FMeasure,H6_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=8.852, p=0.003
# Different distributions (reject H0)

# %%
#https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
from scipy.stats import friedmanchisquare

# compare samples
stat, p = friedmanchisquare(Baseline_FMeasure,H6_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-319e737478c8> in <module>
#       3
#       4 # compare samples
# ----> 5 stat, p = friedmanchisquare(Baseline_FMeasure,H6_FMeasure)
#       6 print('Statistics=%.3f, p=%.3f' % (stat, p))
#       7 # interpret
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py in friedmanchisquare(*args)
#    5926     k = len(args)
#    5927     if k < 3:
# -> 5928         raise ValueError('Less than 3 levels.  Friedman test not appropriate.')
#    5929
#    5930     n = len(args[0])
#
# ValueError: Less than 3 levels.  Friedman test not appropriate.

# %%
#### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(Baseline_FMeasure,H6_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=100.000, p=0.002
# Different distribution (reject H0)

# %%
#Effect_Size RandomForest Vs others   
print(cliffsDelta(Baseline_FMeasure, H6_FMeasure))
#print(cliffsDelta(RF_FMeasure, MLPC_FMeasure))
#print(cliffsDelta(RF_FMeasure, DT_FMeasure))
#print(cliffsDelta(RF_FMeasure, MlkNN_FMeasure)) #divisionByZero error

#Effect_Size LogisticRegression Vs others
#print(cliffsDelta(LogisticRegression_FMeasure, MLPC_FMeasure))
#print(cliffsDelta(LogisticRegression_FMeasure, DT_FMeasure))
#print(cliffsDelta(LogisticRegression_FMeasure, MlkNN_FMeasure))

#Effect_Size MLPC Vs others
#print(cliffsDelta(MLPC_FMeasure, DT_FMeasure))
#print(cliffsDelta(MLPC_FMeasure, MlkNN_FMeasure))

#Effect_Size MlkNN Vs others
#print(cliffsDelta(MlkNN_FMeasure,DT_FMeasure))
# Out:
# (0.6, 'large')

# %%
#Effect_Size RandomForest Vs others   
print('Cohens d: %.3f' % cohend(RF_FMeasure, LogisticRegression_FMeasure))    
print('Cohens d: %.3f' % cohend(RF_FMeasure, MLPC_FMeasure))
print('Cohens d: %.3f' % cohend(RF_FMeasure, DT_FMeasure))
print('Cohens d: %.3f' % cohend(RF_FMeasure, MlkNN_FMeasure))

#Effect_Size LogisticRegression Vs others
print('Cohens d: %.3f' % cohend(LogisticRegression_FMeasure, MLPC_FMeasure))    
print('Cohens d: %.3f' % cohend(LogisticRegression_FMeasure, DT_FMeasure))    
print('Cohens d: %.3f' % cohend(LogisticRegression_FMeasure, MlkNN_FMeasure))    

#Effect_Size MLPC Vs others
print('Cohens d: %.3f' % cohend(MLPC_FMeasure, DT_FMeasure))    
print('Cohens d: %.3f' % cohend(MLPC_FMeasure, MlkNN_FMeasure))    

#Effect_Size MlkNN Vs others
print('Cohens d: %.3f' % cohend(MlkNN_FMeasure,DT_FMeasure))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-391fb3cbb90c> in <module>
#       1 #Effect_Size RandomForest Vs others
# ----> 2 print('Cohens d: %.3f' % cohend(RF_FMeasure, LogisticRegression_FMeasure))
#       3 print('Cohens d: %.3f' % cohend(RF_FMeasure, MLPC_FMeasure))
#       4 print('Cohens d: %.3f' % cohend(RF_FMeasure, DT_FMeasure))
#       5 print('Cohens d: %.3f' % cohend(RF_FMeasure, MlkNN_FMeasure))
#
# NameError: name 'RF_FMeasure' is not defined

# %%
### Wilcoxon paired and dependent samples

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

#from scipy.stats import wilcoxon

#stat, p = wilcoxon(data1, data2)
#print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
#alpha = 0.05
#if p > alpha:
#	print('Same distribution (fail to reject H0)')
#else:
#	print('Different distribution (reject H0)')

# %%
###Precision analysis
#Subsetting data to compute Stats

Baseline_binary = dataBinary[dataBinary.Hypothesis == 'Baseline']
Baseline_Precision = Baseline_binary['Precision']

H6_binary = dataBinary[dataBinary.Hypothesis == 'H6']
H6_Precision = H6_binary['Precision']

# %%
#### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(Baseline_Precision, H6_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=137.000, p=0.013
# Different distribution (reject H0)

# %%
#Effect_Size RandomForest Vs others   
print(cliffsDelta(Baseline_Precision, H6_Precision))
#print(cliffsDelta(RF_Precision, MLPC_Precision))
#print(cliffsDelta(RF_Precision, DT_Precision))
#print(cliffsDelta(RF_Precision, MlkNN_Precision)) #divisionByZero error

#Effect_Size LogisticRegression Vs others
#print(cliffsDelta(LogisticRegression_Precision, MLPC_Precision))
#print(cliffsDelta(LogisticRegression_Precision, DT_Precision))
#print(cliffsDelta(LogisticRegression_Precision, MlkNN_Precision))

#Effect_Size MLPC Vs others
#print(cliffsDelta(MLPC_Precision, DT_Precision))
#print(cliffsDelta(MLPC_Precision, MlkNN_Precision))

#Effect_Size MlkNN Vs others
#print(cliffsDelta(MlkNN_Precision,DT_Precision))
# Out:
# (0.452, 'medium')

# %%
##Kruskall Wallis - Group Comparison

#Fail to Reject H0: Paired sample distributions are equal.
#Reject H0: Paired sample distributions are not equal.
    
from scipy.stats import kruskal
# seed the random number generator


# compare samples
stat, p = kruskal(RF_Precision,LogisticRegression_Precision, MLPC_Precision,DT_Precision,MlkNN_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-a2453d842cc2> in <module>
#       9
#      10 # compare samples
# ---> 11 stat, p = kruskal(RF_Precision,LogisticRegression_Precision, MLPC_Precision,DT_Precision,MlkNN_Precision)
#      12 print('Statistics=%.3f, p=%.3f' % (stat, p))
#      13 # interpret
#
# NameError: name 'RF_Precision' is not defined

# %%
#https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
from scipy.stats import friedmanchisquare

# compare samples
stat, p = friedmanchisquare(RF_Precision,LogisticRegression_Precision, MLPC_Precision,DT_Precision,MlkNN_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-109873b250b2> in <module>
#       3
#       4 # compare samples
# ----> 5 stat, p = friedmanchisquare(RF_Precision,LogisticRegression_Precision, MLPC_Precision,DT_Precision,MlkNN_Precision)
#       6 print('Statistics=%.3f, p=%.3f' % (stat, p))
#       7 # interpret
#
# NameError: name 'RF_Precision' is not defined
